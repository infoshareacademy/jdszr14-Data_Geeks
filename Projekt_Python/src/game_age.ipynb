# %%
import pandas as pd 
import numpy as np

# %%
baza1 = pd.read_csv(r'C:\Users\Michał\Desktop\Kurs DS\Projekty\2\gry\game_data_all.csv', index_col=0)

# %%
baza1
# Out:
#                                    game           link    release  \
# 0                           Pizza Tower  /app/2231450/ 2023-01-26
# 1                       Resident Evil 4  /app/2050650/ 2023-03-24
# 2      The Murder of Sonic the Hedgehog  /app/2324650/ 2023-03-31
# 3                    Pineapple on pizza  /app/2263010/ 2023-03-28
# 4                            Hi-Fi RUSH  /app/1817230/ 2023-01-25
# ...                                 ...            ...        ...
# 67566                   Space Empires V     /app/1690/ 2006-10-16
# 67567  Iron Warriors: T-72 Tank Command     /app/1670/ 2006-07-26
# 67568          Gumboy: Crazy Adventures     /app/2520/ 2006-12-19
# 67569                   Shattered Union     /app/3960/ 2006-10-25
# 67570               Poker Superstars II     /app/4100/ 2006-10-05
#
#        peak_players  positive_reviews  negative_reviews  total_reviews  \
# 0              4529             19807               227          20034
# ...

# %%
#właściwy kod na obliczenie wieku gry
baza1['release'] = pd.to_datetime(baza1['release'])
baza1['rok'] = baza1['release'].dt.year
baza1['game_age'] = 2024 - baza1['rok']
baza1.drop('rok', axis=1)
# Out:
#                                    game           link    release  \
# 0                           Pizza Tower  /app/2231450/ 2023-01-26
# 1                       Resident Evil 4  /app/2050650/ 2023-03-24
# 2      The Murder of Sonic the Hedgehog  /app/2324650/ 2023-03-31
# 3                    Pineapple on pizza  /app/2263010/ 2023-03-28
# 4                            Hi-Fi RUSH  /app/1817230/ 2023-01-25
# ...                                 ...            ...        ...
# 67566                   Space Empires V     /app/1690/ 2006-10-16
# 67567  Iron Warriors: T-72 Tank Command     /app/1670/ 2006-07-26
# 67568          Gumboy: Crazy Adventures     /app/2520/ 2006-12-19
# 67569                   Shattered Union     /app/3960/ 2006-10-25
# 67570               Poker Superstars II     /app/4100/ 2006-10-05
#
#        peak_players  positive_reviews  negative_reviews  total_reviews  \
# 0              4529             19807               227          20034
# ...

# %%
baza1['game_age'].unique()
